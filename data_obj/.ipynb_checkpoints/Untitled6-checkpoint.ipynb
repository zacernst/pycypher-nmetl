# %%
from data_obj.session import Session

# %%
session = Session.load('./demo.pickle.gz')
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ...

# %%
import seaborn as sns

# %%
df = session.table_dict['normalized_default_table'].to_pandas()
column = df['MXxBUE18QVBQTElDQVRJT058MTY5Mzk3NzU3_newrelic.goldenmetrics.apm.application.responseTimeMs_min_normalized']
sns.lineplot(data=column)
# Out:
# <Axes: ylabel='MXxBUE18QVBQTElDQVRJT058MTY5Mzk3NzU3_newrelic.goldenmetrics.apm.application.responseTimeMs_min_normalized'>

# %%
# !uv pip install tensorflow keras
# Out:
# Using Python 3.10.15 environment at /Users/zernst/.venv
# Audited 2 packages in 13ms

# %%
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !poetry add tensorflow
# Out:
# Using version ^2.18.0 for tensorflow
#
# Updating dependencies
# Resolving dependencies... (3.9s)Resolving dependencies... (0.3s)Resolving dependencies... (3.1s)
#
# Package operations: 21 installs, 1 update, 0 removals
#
#   - Downgrading numpy (2.1.2 -> 2.0.2): Pending...
#   - Downgrading numpy (2.1.2 -> 2.0.2): Downloading... 0%
#   - Downgrading numpy (2.1.2 -> 2.0.2): Downloading... 10%
#   - Downgrading numpy (2.1.2 -> 2.0.2): Downloading... 40%
#   - Downgrading numpy (2.1.2 -> 2.0.2): Downloading... 70%
#   - Downgrading numpy (2.1.2 -> 2.0.2): Downloading... 100%
#   - Downgrading numpy (2.1.2 -> 2.0.2): Preparing...
#   - Downgrading numpy (2.1.2 -> 2.0.2): Installing...
#   - Downgrading numpy (2.1.2 -> 2.0.2)
#   - Installing grpcio (1.70.0): Pending...
#   - Installing h5py (3.13.0): Pending...
#   - Installing markdown (3.7): Pending...
#   - Installing ml-dtypes (0.4.1): Pending...
#   - Installing absl-py (2.1.0): Pending...
# ...
